# %%
# imports
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
from functions import *
from qlearning import *

# %%
capacity = 200
alpha = 0.1
gamma = 0.5
epsilon = 0.1
iterations = 1000000
binSize = 10
mu, sigma = 100, 30
demand = np.round(np.random.normal(mu, sigma, 1000000)).astype(np.int32)

q_table = generateQtable(capacity, demand, alpha, gamma, epsilon, iterations, binSize)
q_policies = generateQpolicies(q_table)

# %%
plt.plot(range(0, capacity+1, binSize), q_policies)
